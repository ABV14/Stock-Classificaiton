# %%
pip install wordcloud

# %%
import pandas as pd
import os

directory = '/content/sample_data/Text Data' #Replace with folder containing your text data

# %%
def preprocess_text(text):
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'\$(?=[a-zA-Z])', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s.]', '', text)
    return text

# %%
csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]
for csv_file in csv_files:
    df = pd.read_csv(os.path.join(directory, csv_file))

    df['text'] = df['text'].apply(preprocess_text)

    all_text = ' '.join(df['text'])

    words = all_text.split() # Tokenize the text into words

    word_freq = Counter(words) # Count the frequency of each word


    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)     # Generate word cloud

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for {csv_file}')
    plt.axis('off')
    plt.show()
